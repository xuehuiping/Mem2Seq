# %% [raw]
# 2020-04-19 19:20:44 分析日志

# %%
lines = open('log.4.19.txt').readlines()
for line in lines:
    line = line.strip()
    if not line.startswith('L:') and not line.startswith('R') and not line.startswith('0%|'):
        print(line)
# Out:
# 04-19 14:53 Reading lines from data/dialog-bAbI-tasks/dialog-babi-task1trn.txt
# 04-19 14:53 Pointer percentace= 0.23558445004643758
# 04-19 14:53 Max responce Len: 9
# 04-19 14:53 Max Input Len: 73
# 04-19 14:53 Avg. User Utterances: 4.024
# 04-19 14:53 Avg. Bot Utterances: 6.024
# 04-19 14:53 Avg. KB results: 0.0
# 04-19 14:53 Avg. responce Len: 6.255810092961488
# 04-19 14:53 Reading lines from data/dialog-bAbI-tasks/dialog-babi-task1dev.txt
# 04-19 14:53 Pointer percentace= 0.23736755231350834
# 04-19 14:53 Max responce Len: 9
# 04-19 14:53 Max Input Len: 73
# 04-19 14:53 Avg. User Utterances: 4.015
# 04-19 14:53 Avg. Bot Utterances: 6.015
# 04-19 14:53 Avg. KB results: 0.0
# 04-19 14:53 Avg. responce Len: 6.244721529509559
# 04-19 14:53 Reading lines from data/dialog-bAbI-tasks/dialog-babi-task1tst.txt
# 04-19 14:53 Pointer percentace= 0.2377867746288799
# 04-19 14:53 Max responce Len: 9
# 04-19 14:53 Max Input Len: 73
# 04-19 14:53 Avg. User Utterances: 3.936
# ...

# %% [raw]
# 最好的结果是
# 04-19 15:19 Epoch:33
#
# 04-19 15:20 STARTING EVALUATION
#
# 04-19 15:21 Dialog Accuracy:	1.0
# 04-19 15:21 BLEU SCORE:100.0

# %%
试试predict、evelution
